# %%
import requests
import os
import pandas as pd

# %%
bearer_token = os.environ.get("BEARER_TOKEN")

# %%
def create_url(): 
    user_id = 2244994945
    return "https://api.twitter.com/2/users/{}/tweets".format(user_id)

# %%
url = create_url()
print(url)
# Out:
# https://api.twitter.com/2/users/2244994945/tweets

# %%
params = {"tweet.fields": "created_at,lang", "max_results":"50"}

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
headers = create_headers(bearer_token)

# %%
def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", url, headers=headers, params=params)
    print(response.status_code)
    return response.json()

# %%
response = connect_to_endpoint(url, headers, params)
# Out:
# 200

# %%
print(response)
# Out:
# {'data': [{'id': '1371853548762333187', 'created_at': '2021-03-16T15:59:08.000Z', 'text': 'Live now! https://t.co/sC2M3eRpPk', 'lang': 'en'}, {'id': '1371588329368657923', 'created_at': '2021-03-15T22:25:15.000Z', 'text': 'Hope to see you tomorrow at 12 pm EST! \nhttps://t.co/GrtBOXyHmB https://t.co/sC2M3eRpPk', 'lang': 'en'}, {'id': '1371363033352638467', 'created_at': '2021-03-15T07:30:00.000Z', 'text': "🔎 If you're using v2 full-archive search for Academic Research, you won't want to miss this livestream hosted by our research dev advocate @suhemparack.\n\nMark your calendars to join us on https://t.co/GrtBOXyHmB Thursday March 18th, 10AM PT/ 1PM ET. https://t.co/SpuOoD7Dm8", 'lang': 'en'}, {'id': '1370110639545417729', 'created_at': '2021-03-11T20:33:26.000Z', 'text': "On Tuesday at 12 pm EST, @jessicagarson will cover how to start working with the data returned from v2 of the #twitterapi  \n\nShe'll be focusing on how to work with nested JSON and sending your data to a CSV. \n\nJoin us on Twitch!\nhttps://t.co/GrtBOXyHmB", 'lang': 'en'}, {'id': '1370028373792071687', 'created_at': '2021-03-11T15:06:32.000Z', 'text': '“I have been a developer from a young age,” says @yesnoornext. @marie_dm_ “started coding in engineering school, where I discovered a strong interest in tech. We always wanted to create something that can help people to follow things they love and save information that matters.”', 'lang': 'en'}, {'id': '1370028372701585408', 'created_at': '2021-03-11T15:06:32.000Z', 'text': '“The idea of Threader came from the desire to highlight the amazing stories and knowledge shared on Twitter,” explain @marie_dm_ and @yesnoornext. “As threads became popular, they were hard to find or read. We decided to build an app to retrieve and save this great content.”', 'lang': 'en'}, {'id': '1370028371585814532', 'created_at': '2021-03-11T15:06:32.000Z', 'text': 'Twitter is where people come to share, learn, and tell stories. @threader_app was made to improve how people read these stories. It’s an app that compiles threads and allows you to save your favorites. https://t.co/YqKmQPbR6u', 'lang': 'en'}, {'id': '1367519325871992833', 'created_at': '2021-03-04T16:56:29.000Z', 'text': '“I always wanted my work to speak for me, and be out there for others in the world to use and admire,” says @JPEGuin. “It fills me with a sense of accomplishment to be able to see people use my products, and liking them, after putting in countless hours of hard work and effort.”', 'lang': 'en'}, {'id': '1367519324911529985', 'created_at': '2021-03-04T16:56:28.000Z', 'text': 'Building on the newest features of both the #TwitterAPI and iOS was the inspiration for @JPEGuin, creator of @AviaryTheApp. “I wanted to make something that uses the latest iOS 14 features, whilst being fully feature-rich so users can make the most of it.”', 'lang': 'en'}, {'id': '1367519323925843968', 'created_at': '2021-03-04T16:56:28.000Z', 'text
# 40  1339682027885522947  2020-12-17T21:21:00.000Z
# 41  1339662151749910528  2020-12-17T20:02:01.000Z
# 42  1339641862265696256  2020-12-17T18:41:23.000Z
# 43  1339641861263245315  2020-12-17T18:41:23.000Z
# 44  1338971066773905408  2020-12-15T22:15:53.000Z
# 45  1338923691497959425  2020-12-15T19:07:38.000Z
# 46  1337498609819021312  2020-12-11T20:44:52.000Z
# 47  1337464482654793740  2020-12-11T18:29:16.000Z
# 48  1337122535188652033  2020-12-10T19:50:29.000Z
# 49  1337122534173663235  2020-12-10T19:50:29.000Z
#
#                                                  text lang
# 0                   Live now! https://t.co/sC2M3eRpPk   en
# 1   Hope to see you tomorrow at 12 pm EST! \nhttps...   en
# 2   🔎 If you're using v2 full-archive search for A...   en
# 3   On Tuesday at 12 pm EST, @jessicagarson will c...   en
# 4   “I have been a developer from a young age,” sa...   en
# 5   “The idea of Threader came from the desire to ...   en
# 6   Twitter is where people come to share, learn, ...   en
# 7   “I always wanted my work to speak for me, and ...   en
# 8   Building on the newest features of both the #T...   en
# 9   Meet Aviary, a modern client for iOS 14 built ...   en
# 10  This change will help us focus on delivering v...   en
# 11  During our analysis, we discovered only 0.52% ...   en
# 12  Embedded timelines are a great way to add a se...   en
# 13  The new #TwitterAPI provides the ability to bu...   en
# 14  We’re excited to start in about 30 minutes! Do...   en
# 15  “Making things is magical,” in @aaronykng’s ow...   en
# 16  “I was heading to a design conference in New Y...   en
# 17  Twitter is where “let me know how I can help” ...   en
# 18  @a_larsson @suhemparack Unfortunately there wo...   en
# 19  If you're newly approved for the Academic Rese...   en
# 20  From our living rooms to yours 🐱‍💻🛋️Our develo...   en
# 21  “To quote my creator Jerome Gangneux, I always...   en
# 22  “In the 20th century, managers managed humans,...   en
# 23  Meet one of the useful Twitter bots out there:...   en
# 24  Valentine’s Day is approaching! 💙\n\nOver the ...   en
# 25  Go ahead, follow another puppy account. We won...   en
# 26  Learn how academics can get historical Tweets ...   en
# 27  Who knew an API could be delicious? https://t....   en
# 28  RT @TwitterOSS: Today we’re happy to share Twi...   en
# 29  We’re excited to support so many more research...   en
# 30  We know this doesn't represent everyone doing ...   en
# 31  To be eligible for this track, you need to:\n•...   en
# 32  To get started, new and returning developers m...   en
# 33  Feedback from hundreds of researchers around t...   en
# 34  Academics are one of the biggest groups using ...   en
# 35  Learn how to use the user Tweet timeline and u...   en
# 36  🔑🔑 On Tuesday, January 12th, we’re removing th...   en
# 37  📈 From Tweets to Google Sheets: @JessicaGarson...   en
# 38  Introducing a new Tweet field on v2 endpoints:...   en
# 39  👋 We're going live on Twitch in just a few min...   en
# 40  Now in the new #TwitterAPI: user Tweet timelin...   en
# 41  👀 Don’t sign off for the holidays just yet. We...   en
# 42  2021 can't come fast enough, but when it does,...   en
# 43  📣 We’re releasing new v2 endpoints today! The ...   en
# 44  💡 Using Twitter data for academic research? Jo...   en
# 45  📈 Live now with @jessicagarson and @i_am_danie...   en
# 46  Thanks to everyone who tuned in today to make ...   en
# 47  🎧💻 We're live! Tune in! 🎶 https://t.co/FSYP4rJdHr   en
# 48  👂We want to hear what you think about our plan...   en
# 49  Is 2020 over yet?\nDespite everything that hap...   en

# %%
df.to_csv('simple.csv')
