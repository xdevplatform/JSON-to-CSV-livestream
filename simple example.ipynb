# %%
import requests
import os
import json
import pandas as pd

# %%
bearer_token = os.environ.get("BEARER_TOKEN")

# %%
def create_url(): 
    user_id = 2244994945
    return "https://api.twitter.com/2/users/{}/tweets".format(user_id)

# %%
url = create_url()
print(url)
# Out:
# https://api.twitter.com/2/users/2244994945/tweets

# %%
params = {"tweet.fields": "created_at,lang", "max_results":"50"}

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
headers = create_headers(bearer_token)

# %%
def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", url, headers=headers, params=params)
    print(response.status_code)
    return response.json()

# %%
response = connect_to_endpoint(url, headers, params)
# Out:
# 200

# %%
print(response)
# Out:
# {'data': [{'text': "🔎 If you're using v2 full-archive search for Academic Research, you won't want to miss this livestream hosted by our research dev advocate @suhemparack.\n\nMark your calendars to join us on https://t.co/GrtBOXyHmB Thursday March 18th, 10AM PT/ 1PM ET. https://t.co/SpuOoD7Dm8", 'created_at': '2021-03-15T07:30:00.000Z', 'lang': 'en', 'id': '1371363033352638467'}, {'text': "On Tuesday at 12 pm EST, @jessicagarson will cover how to start working with the data returned from v2 of the #twitterapi  \n\nShe'll be focusing on how to work with nested JSON and sending your data to a CSV. \n\nJoin us on Twitch!\nhttps://t.co/GrtBOXyHmB", 'created_at': '2021-03-11T20:33:26.000Z', 'lang': 'en', 'id': '1370110639545417729'}, {'text': '“I have been a developer from a young age,” says @yesnoornext. @marie_dm_ “started coding in engineering school, where I discovered a strong interest in tech. We always wanted to create something that can help people to follow things they love and save information that matters.”', 'created_at': '2021-03-11T15:06:32.000Z', 'lang': 'en', 'id': '1370028373792071687'}, {'text': '“The idea of Threader came from the desire to highlight the amazing stories and knowledge shared on Twitter,” explain @marie_dm_ and @yesnoornext. “As threads became popular, they were hard to find or read. We decided to build an app to retrieve and save this great content.”', 'created_at': '2021-03-11T15:06:32.000Z', 'lang': 'en', 'id': '1370028372701585408'}, {'text': 'Twitter is where people come to share, learn, and tell stories. @threader_app was made to improve how people read these stories. It’s an app that compiles threads and allows you to save your favorites. https://t.co/YqKmQPbR6u', 'created_at': '2021-03-11T15:06:32.000Z', 'lang': 'en', 'id': '1370028371585814532'}, {'text': '“I always wanted my work to speak for me, and be out there for others in the world to use and admire,” says @JPEGuin. “It fills me with a sense of accomplishment to be able to see people use my products, and liking them, after putting in countless hours of hard work and effort.”', 'created_at': '2021-03-04T16:56:29.000Z', 'lang': 'en', 'id': '1367519325871992833'}, {'text': 'Building on the newest features of both the #TwitterAPI and iOS was the inspiration for @JPEGuin, creator of @AviaryTheApp. “I wanted to make something that uses the latest iOS 14 features, whilst being fully feature-rich so users can make the most of it.”', 'created_at': '2021-03-04T16:56:28.000Z', 'lang': 'en', 'id': '1367519324911529985'}, {'text': 'Meet Aviary, a modern client for iOS 14 built using the new Twitter API. It has a beautiful UI and great widgets to keep you up to date with the latest Tweets. https://t.co/95cbd253jK', 'created_at': '2021-03-04T16:56:28.000Z', 'lang': 'en', 'id': '1367519323925843968'}, {'text': 'This change will help us focus on delivering value to the &gt;99% of people currently using Profiles &amp; Lists timelines. You should see these features become faster, easier to use, and more up-to-date with Twitter features and functionality. \n\nLearn more 📖\n\nhttps://t.co/HzeJLglpRn', 'created_at': '2021-03-03T18:07:07.000Z', 'lang': 'en', 'id': '1367174713252868102'}, {'text': 'During our analysis, we discovered only 0.52% of domains use the Likes timeline, Collections timeline, and Moments timeline. Because of the very low usage, we plan to retire these timelines on June 23, 2021.', 'created_at': '2021-03-03T18:07:06.000Z', 'lang': 'en', 'id': '1367174712397209602'}, {'text': 'Embedded timelines are a great way to add a set of Tweets (known as a timeline) to your own website. As Twitter continues to improve our underlying systems, we performed an analysis of the various embeddable timelines available. 🧮', 'created_at': '2021-03-03T18:07:06.000Z', 'lang': 'en', 'id': '1367174711625482243'}, {'text': 'The new #TwitterAPI provides the ability to build the Tweet payload with the fields that you want. \n\nIn this tutorial @suhemparack expl ...

# %%
df = pd.DataFrame(response['data'])

# %%
df
# Out:
#                                                  text  \
# 0   🔎 If you're using v2 full-archive search for A...
# 1   On Tuesday at 12 pm EST, @jessicagarson will c...
# 2   “I have been a developer from a young age,” sa...
# 3   “The idea of Threader came from the desire to ...
# 4   Twitter is where people come to share, learn, ...
# 5   “I always wanted my work to speak for me, and ...
# 6   Building on the newest features of both the #T...
# 7   Meet Aviary, a modern client for iOS 14 built ...
# 8   This change will help us focus on delivering v...
# 9   During our analysis, we discovered only 0.52% ...
# 10  Embedded timelines are a great way to add a se...
# 11  The new #TwitterAPI provides the ability to bu...
# 12  We’re excited to start in about 30 minutes! Do...
# 13  “Making things is magical,” in @aaronykng’s ow...
# 14  “I was heading to a design conference in New Y...
# 15  Twitter is where “let me know how I can help” ...
# 16  @a_larsson @suhemparack Unfortunately there wo...
# 17  If you're newly approved for the Academic Rese...
# 18  From our living rooms to yours 🐱‍💻🛋️Our develo...
# 19  “To quote my creator Jerome Gangneux, I always...
# 20  “In the 20th century, managers managed humans,...
# 21  Meet one of the useful Twitter bots out there:...
# 22  Valentine’s Day is approaching! 💙\n\nOver the ...
# 23  Go ahead, follow another puppy account. We won...
# 24  Learn how academics can get historical Tweets ...
# 25  Who knew an API could be delicious? https://t....
# 26  RT @TwitterOSS: Today we’re happy to share Twi...
# 27  We’re excited to support so many more research...
# 28  We know this doesn't represent everyone doing ...
# 29  To be eligible for this track, you need to:\n•...
# 30  To get started, new and returning developers m...
# 31  Feedback from hundreds of researchers around t...
# 32  Academics are one of the biggest groups using ...
# 33  Learn how to use the user Tweet timeline and u...
# 34  🔑🔑 On Tuesday, January 12th, we’re removing th...
# 35  📈 From Tweets to Google Sheets: @JessicaGarson...
# 36  Introducing a new Tweet field on v2 endpoints:...
# 37  👋 We're going live on Twitch in just a few min...
# 38  Now in the new #TwitterAPI: user Tweet timelin...
# 39  👀 Don’t sign off for the holidays just yet. We...
# 40  2021 can't come fast enough, but when it does,...
# 41  📣 We’re releasing new v2 endpoints today! The ...
# 42  💡 Using Twitter data for academic research? Jo...
# 43  📈 Live now with @jessicagarson and @i_am_danie...
# 44  Thanks to everyone who tuned in today to make ...
# 45  🎧💻 We're live! Tune in! 🎶 https://t.co/FSYP4rJdHr
# 46  👂We want to hear what you think about our plan...
# 47  Is 2020 over yet?\nDespite everything that hap...
# 48  🎧 Headphones on: watch @jessicagarson build an...
