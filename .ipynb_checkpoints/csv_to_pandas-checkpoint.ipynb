# %%
import pandas as pd

# %%
df = pd.read_csv('response_csvkit.csv')

# %%
df
# Out:
#     author_id  entities/annotations/0/start  entities/annotations/0/end  \
# 0  2244994945                         221.0                       226.0
# 1  2244994945                           NaN                         NaN
# 2  2244994945                          13.0                        20.0
# 3  2244994945                           0.0                         6.0
# 4  2244994945                           NaN                         NaN
#
#    entities/annotations/0/probability entities/annotations/0/type  \
# 0                              0.4652                     Product
# 1                                 NaN                         NaN
# 2                              0.3405                      Person
# 3                              0.5394                     Product
# 4                                 NaN                         NaN
#
#   entities/annotations/0/normalized_text  entities/hashtags/0/start  \
# ...
