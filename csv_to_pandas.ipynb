# %%
import pandas as pd

# %%
df = pd.read_csv('res_csv.csv')

# %%
df
# Out:
#             source                 created_at lang   author_id  \
# 0  Twitter Web App  2021-03-16T15:59:08+00:00   en  2244994945
# 1  Twitter Web App  2021-03-15T22:25:15+00:00   en  2244994945
# 2  Twitter Web App  2021-03-15T07:30:00+00:00   en  2244994945
# 3  Twitter Web App  2021-03-11T20:33:26+00:00   en  2244994945
# 4  Twitter Web App  2021-03-11T15:06:32+00:00   en  2244994945
#
#   referenced_tweets/0/type  referenced_tweets/0/id      conversation_id  \
# 0                   quoted            1.370111e+18  1371853548762333187
# 1                   quoted            1.370111e+18  1371588329368657923
# 2                   quoted            1.367898e+18  1371363033352638467
# 3                      NaN                     NaN  1370110639545417729
# 4               replied_to            1.370028e+18  1370028371585814532
#
#                                                 text reply_settings  \
# 0                  Live now! https://t.co/sC2M3eRpPk       everyone
# ...
